# %% [markdown]
# <a id='model5'></a>
# ### (OPTIONAL IMPLEMENTATION) Models 5+
#
# If you would like to try out more architectures than the ones above, please use the code cell below.  Please continue to follow the same convention for saving the models; for the $i$-th sample model, please save the loss at **`model_i.pickle`** and saving the trained model at **`model_i.h5`**.

# %%
## (Optional) TODO: Try out some more models!
### Feel free to use as many code cells as needed.
model_5 = deep_bidirectional_rnn_model(input_dim=161, units=200, recur_layers=2)
train_model(input_to_softmax=model_5, 
            pickle_path='model_5.pickle', 
            save_model_path='model_5.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, None, 400)         579200
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 1,552,429
# Trainable params: 1,552,429
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 498s - loss: 332.2385 - val_loss: 239.1250
# Epoch 2/20
# 101/101 [==============================] - 507s - loss: 234.8406 - val_loss: 219.6250
# Epoch 3/20
# 101/101 [==============================] - 510s - loss: 219.4031 - val_loss: 201.6159
# Epoch 4/20
# 101/101 [==============================] - 506s - loss: 196.6255 - val_loss: 180.7016
# Epoch 5/20
# 101/101 [==============================] - 515s - loss: 174.4888 - val_loss: 164.7066
# Epoch 6/20
# 101/101 [==============================] - 505s - loss: 157.7204 - val_loss: 154.1140
# Epoch 7/20
# 101/101 [==============================] - 513s - loss: 144.0780 - val_loss: 144.2763
# Epoch 8/20
# 101/101 [==============================] - 509s - loss: 132.6384 - val_loss: 139.6942
# Epoch 9/20
# 101/101 [==============================] - 514s - loss: 123.3800 - val_loss: 137.8833
# Epoch 10/20
# 101/101 [==============================] - 516s - loss: 115.9780 - val_loss: 131.6866
# Epoch 11/20
# 101/101 [==============================] - 522s - loss: 109.0990 - val_loss: 129.7730
# Epoch 12/20
# 101/101 [==============================] - 509s - loss: 102.8585 - val_loss: 129.4434
# Epoch 13/20
# 101/101 [==============================] - 512s - loss: 97.2896 - val_loss: 126.9523
# Epoch 14/20
# 101/101 [==============================] - 511s - loss: 91.6641 - val_loss: 129.7652
# Epoch 15/20
# 101/101 [==============================] - 513s - loss: 86.8321 - val_loss: 130.3460
# Epoch 16/20
# 101/101 [==============================] - 507s - loss: 81.9424 - val_loss: 128.3709
# Epoch 17/20
# 101/101 [==============================] - 514s - loss: 77.3329 - val_loss: 131.2814
# Epoch 18/20
# 101/101 [==============================] - 513s - loss: 72.6065 - val_loss: 130.7051
# Epoch 19/20
# 101/101 [==============================] - 513s - loss: 68.1413 - val_loss: 133.5859
# Epoch 20/20
# 101/101 [==============================] - 513s - loss: 63.6451 - val_loss: 136.8060

# %% [markdown]
# <a id='compare'></a>
# ### Compare the Models
#
# Execute the code cell below to evaluate the performance of the drafted deep learning models.  The training and validation loss are plotted for each model.

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

# obtain the paths for the saved model history
all_pickles = sorted(glob("results/model_?.pickle"))
# extract the name of each model
model_names = [item[8:-7] for item in all_pickles]
# extract the loss history for each model
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
# save the number of epochs used to train each model
num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

fig = plt.figure(figsize=(16,5))

# plot the training loss vs. epoch for each model
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
# clean up the plot
ax1.legend()  
ax1.set_xlim([1, max(num_epochs)])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')

# plot the validation loss vs. epoch for each model
ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
# clean up the plot
ax2.legend()  
ax2.set_xlim([1, max(num_epochs)])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.show()

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

# obtain the paths for the saved model history
all_pickles = sorted(glob("results/model_?.pickle"))
# extract the name of each model
model_names = [item[8:-7] for item in all_pickles]
# extract the loss history for each model
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
# save the number of epochs used to train each model
num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

fig = plt.figure(figsize=(16,5))

# plot the training loss vs. epoch for each model
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
# clean up the plot
ax1.legend()  
ax1.set_xlim([1, max(num_epochs)])
ax1.set_ylim([50, 250])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')

# plot the validation loss vs. epoch for each model
ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
# clean up the plot
ax2.legend()  
ax2.set_xlim([1, max(num_epochs)])
ax2.set_ylim([125, 200])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.show()

# %% [markdown]
# __Question 1:__ Use the plot above to analyze the performance of each of the attempted architectures.  Which performs best?  Provide an explanation regarding why you think some models perform better than others.
#
# __Answer:__
#
# Model 3 (Deeper RNN + TimeDistributed Dense) performed the best among the default 5 models. The following are the analysis of the performance of each of the attempted architectures (from the best to worst):
#
# 1) Model 3 Deeper RNN (GRU) + TimeDistributed Dense: This model did not have the best result during the training (training loss was 3rd among the default 5 models). However, the validation loss was continually decreasing over each epoch of training compared to the other models due to the implementation of multiple layers; hence this model performed the best. Also, this model only used two layers of RNN; however, more layers can be added to the model to increase its accuracy further.
#
# 2) Model 2 CNN + RNN (GRU) + TimeDistributed Dense: This model had the lowest training loss among the default 5 models; however, the model was overfitting to the training dataset as the validation loss started to increase after 12 epochs of training. Dropout can be added to the model to mitigate the overfitting problem and further improve the validation loss.
#
# 3) Model 1 RNN (GRU) + TimeDistributed Dense: This model had the worst training loss, however, had a lower validation loss than Model 4 since the model was not overfitting to the training dataset. Also, since the techniques implemented in this model were only a batch normalization and TimeDistributed layer, the model did not improve after 14 epochs of training as the training loss has stabilized after 14 epochs of training.
#
# 4) Model 4 Bidirectional RNN (GRU) + TimeDistributed Dense: This model outperformed Model 3 (Deeper RNN + TimeDistributed Dense) during training with the training loss of about 104; however, the model was overfitting to the training dataset, and the performance was bad during validation (loss of about 153).
#
# 5) Model 0 RNN (GRU): The performance of this model was significantly worse among the default 5 models because both the training and validation loss did not decrease every epoch of training. However, this problem can be mitigated by implementing a batch normalization to the model as observed in Model 1 (RNN + TimeDistributed Dense).
#
# Optional Implementation (Model 5):
# As described in "Speech Recognition with Deep Recurrent Neural Networks" by Alex Graves, Abdel-rahman Mohamed, and Geoffrey Hinton, the combination of deep, bidirectional Long Short-term Memory (LSTM) RNNs with end-to-end training and weight noise gave state-of-the-art results in phoneme recognition on the TIMIT database. Hence, I built a model of deep bidirectional LSTM as Model 5 to compare the performance with other default 5 models above. The results were similar as described in the paper, where the validation loss of deep bidirectional LSTM model outperformed all default 5 models although the model was somewhat overfitting to the training dataset (training loss 64 vs. validation loss 137).

# %% [markdown]
# <a id='final'></a>
# ### (IMPLEMENTATION) Final Model
#
# Now that you've tried out many sample models, use what you've learned to draft your own architecture!  While your final acoustic model should not be identical to any of the architectures explored above, you are welcome to merely combine the explored layers above into a deeper architecture.  It is **NOT** necessary to include new layer types that were not explored in the notebook.
#
# However, if you would like some ideas for even more layer types, check out these ideas for some additional, optional extensions to your model:
#
# - If you notice your model is overfitting to the training dataset, consider adding **dropout**!  To add dropout to [recurrent layers](https://faroit.github.io/keras-docs/1.0.2/layers/recurrent/), pay special attention to the `dropout_W` and `dropout_U` arguments.  This [paper](http://arxiv.org/abs/1512.05287) may also provide some interesting theoretical background.
# - If you choose to include a convolutional layer in your model, you may get better results by working with **dilated convolutions**.  If you choose to use dilated convolutions, make sure that you are able to accurately calculate the length of the acoustic model's output in the `model.output_length` lambda function.  You can read more about dilated convolutions in Google's [WaveNet paper](https://arxiv.org/abs/1609.03499).  For an example of a speech-to-text system that makes use of dilated convolutions, check out this GitHub [repository](https://github.com/buriburisuri/speech-to-text-wavenet).  You can work with dilated convolutions [in Keras](https://keras.io/layers/convolutional/) by paying special attention to the `padding` argument when you specify a convolutional layer.
# - If your model makes use of convolutional layers, why not also experiment with adding **max pooling**?  Check out [this paper](https://arxiv.org/pdf/1701.02720.pdf) for example architecture that makes use of max pooling in an acoustic model.
# - So far, you have experimented with a single bidirectional RNN layer.  Consider stacking the bidirectional layers, to produce a [deep bidirectional RNN](https://www.cs.toronto.edu/~graves/asru_2013.pdf)!
#
# All models that you specify in this repository should have `output_length` defined as an attribute.  This attribute is a lambda function that maps the (temporal) length of the input acoustic features to the (temporal) length of the output softmax layer.  This function is used in the computation of CTC loss; to see this, look at the `add_ctc_loss` function in `train_utils.py`.  To see where the `output_length` attribute is defined for the models in the code, take a look at the `sample_models.py` file.  You will notice this line of code within most models:
# ```
# model.output_length = lambda x: x
# ```
# The acoustic model that incorporates a convolutional layer (`cnn_rnn_model`) has a line that is a bit different:
# ```
# model.output_length = lambda x: cnn_output_length(
#         x, kernel_size, conv_border_mode, conv_stride)
# ```
#
# In the case of models that use purely recurrent layers, the lambda function is the identity function, as the recurrent layers do not modify the (temporal) length of their input tensors.  However, convolutional layers are more complicated and require a specialized function (`cnn_output_length` in `sample_models.py`) to determine the temporal length of their output.
#
# You will have to add the `output_length` attribute to your final model before running the code cell below.  Feel free to use the `cnn_output_length` function, if it suits your model.

# %%
# specify the model
model_end_20 = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3,
                        dropout_rate=0.2
                        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 200)         354400
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,931,629
# Trainable params: 2,931,229
# Non-trainable params: 400
# _________________________________________________________________
# None

# %% [markdown]
# Please execute the code cell below to train the neural network you specified in `input_to_softmax`.  After the model has finished training, the model is [saved](https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model) in the HDF5 file `model_end.h5`.  The loss history is [saved](https://wiki.python.org/moin/UsingPickle) in `model_end.pickle`.  You are welcome to tweak any of the optional parameters while calling the `train_model` function, but this is not required.

# %%
train_model(input_to_softmax=model_end_20, 
            pickle_path='model_end_20.pickle', 
            save_model_path='model_end_20.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/20
# 101/101 [==============================] - 350s - loss: 254.6322 - val_loss: 220.5642
# Epoch 2/20
# 101/101 [==============================] - 359s - loss: 215.4243 - val_loss: 192.5770
# Epoch 3/20
# 101/101 [==============================] - 359s - loss: 187.5623 - val_loss: 165.4251
# Epoch 4/20
# 101/101 [==============================] - 362s - loss: 165.9054 - val_loss: 151.5021
# Epoch 5/20
# 101/101 [==============================] - 360s - loss: 150.8961 - val_loss: 141.3768
# Epoch 6/20
# 101/101 [==============================] - 361s - loss: 138.8033 - val_loss: 133.5056
# Epoch 7/20
# 101/101 [==============================] - 357s - loss: 129.7319 - val_loss: 124.9768
# Epoch 8/20
# 101/101 [==============================] - 359s - loss: 122.9000 - val_loss: 120.2029
# Epoch 9/20
# 101/101 [==============================] - 359s - loss: 116.5751 - val_loss: 117.2957
# Epoch 10/20
# 101/101 [==============================] - 362s - loss: 111.1513 - val_loss: 114.1480
# Epoch 11/20
# 101/101 [==============================] - 362s - loss: 106.6514 - val_loss: 111.2906
# Epoch 12/20
# 101/101 [==============================] - 361s - loss: 102.0575 - val_loss: 109.5043
# Epoch 13/20
# 101/101 [==============================] - 357s - loss: 98.1072 - val_loss: 107.0432
# Epoch 14/20
# 101/101 [==============================] - 358s - loss: 94.3726 - val_loss: 104.4849
# Epoch 15/20
# 101/101 [==============================] - 362s - loss: 91.2544 - val_loss: 106.6088
# Epoch 16/20
# 101/101 [==============================] - 358s - loss: 88.1377 - val_loss: 105.2409
# Epoch 17/20
# 101/101 [==============================] - 360s - loss: 85.1976 - val_loss: 101.8260
# Epoch 18/20
# 101/101 [==============================] - 361s - loss: 82.3842 - val_loss: 102.3709
# Epoch 19/20
# 101/101 [==============================] - 358s - loss: 79.4430 - val_loss: 101.0743
# Epoch 20/20
# 101/101 [==============================] - 362s - loss: 77.0151 - val_loss: 101.0795

# %%
# Use MFCC features
model_end_20_MFCC = final_model(input_dim=13, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3,
                        dropout_rate=0.2
                        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 200)         28800
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,606,029
# Trainable params: 2,605,629
# Non-trainable params: 400
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_end_20_MFCC, 
            pickle_path='model_end_20_MFCC.pickle', 
            save_model_path='model_end_20_MFCC.h5', 
            spectrogram=False) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/20
# 101/101 [==============================] - 359s - loss: 247.7380 - val_loss: 215.7204
# Epoch 2/20
# 101/101 [==============================] - 364s - loss: 212.7826 - val_loss: 192.7646
# Epoch 3/20
# 101/101 [==============================] - 362s - loss: 187.0687 - val_loss: 168.2796
# Epoch 4/20
# 101/101 [==============================] - 365s - loss: 164.3125 - val_loss: 147.8541
# Epoch 5/20
# 101/101 [==============================] - 367s - loss: 147.8229 - val_loss: 135.4018
# Epoch 6/20
# 101/101 [==============================] - 363s - loss: 135.8528 - val_loss: 128.0212
# Epoch 7/20
# 101/101 [==============================] - 364s - loss: 126.6274 - val_loss: 119.4744
# Epoch 8/20
# 101/101 [==============================] - 365s - loss: 119.1074 - val_loss: 116.2593
# Epoch 9/20
# 101/101 [==============================] - 363s - loss: 113.1733 - val_loss: 113.2734
# Epoch 10/20
# 101/101 [==============================] - 364s - loss: 107.8546 - val_loss: 109.9418
# Epoch 11/20
# 101/101 [==============================] - 363s - loss: 103.2027 - val_loss: 107.8240
# Epoch 12/20
# 101/101 [==============================] - 363s - loss: 99.4051 - val_loss: 105.6665
# Epoch 13/20
# 101/101 [==============================] - 364s - loss: 95.4933 - val_loss: 104.7997
# Epoch 14/20
# 101/101 [==============================] - 364s - loss: 92.1240 - val_loss: 102.4501
# Epoch 15/20
# 101/101 [==============================] - 365s - loss: 89.0900 - val_loss: 100.7465
# Epoch 16/20
# 101/101 [==============================] - 366s - loss: 86.1066 - val_loss: 101.3301
# Epoch 17/20
# 101/101 [==============================] - 365s - loss: 83.6632 - val_loss: 100.2411
# Epoch 18/20
# 101/101 [==============================] - 365s - loss: 80.5338 - val_loss: 101.0052
# Epoch 19/20
# 101/101 [==============================] - 362s - loss: 77.9976 - val_loss: 98.0082
# Epoch 20/20
# 101/101 [==============================] - 362s - loss: 75.8203 - val_loss: 97.5483

# %%
# Training for 30 epochs
from train_utils2 import train_model

# %%
model_end_30_02 = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3,
                        dropout_rate=0.2
                        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 200)         354400
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_11 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,931,629
# Trainable params: 2,931,229
# Non-trainable params: 400
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_end_30_02, 
            pickle_path='model_end_30_02.pickle', 
            save_model_path='model_end_30_02.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_end_30_03, 
            pickle_path='model_end_30_03.pickle', 
            save_model_path='model_end_30_03.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/30
# 101/101 [==============================] - 365s - loss: 257.3190 - val_loss: 224.4432
# Epoch 2/30
# 101/101 [==============================] - 374s - loss: 219.5970 - val_loss: 196.8573
# Epoch 3/30
# 101/101 [==============================] - 373s - loss: 195.2296 - val_loss: 172.8180
# Epoch 4/30
# 101/101 [==============================] - 371s - loss: 174.0689 - val_loss: 157.6616
# Epoch 5/30
# 101/101 [==============================] - 376s - loss: 159.2829 - val_loss: 146.5790
# Epoch 6/30
# 101/101 [==============================] - 375s - loss: 147.5118 - val_loss: 136.5756
# Epoch 7/30
# 101/101 [==============================] - 374s - loss: 138.5751 - val_loss: 128.1207
# Epoch 8/30
# 101/101 [==============================] - 374s - loss: 131.9221 - val_loss: 125.1222
# Epoch 9/30
# 101/101 [==============================] - 376s - loss: 125.5435 - val_loss: 121.2164
# Epoch 10/30
# 101/101 [==============================] - 376s - loss: 120.9004 - val_loss: 117.9315
# Epoch 11/30
# 101/101 [==============================] - 376s - loss: 116.7366 - val_loss: 114.5383
# Epoch 12/30
# 101/101 [==============================] - 378s - loss: 112.4108 - val_loss: 112.6018
# Epoch 13/30
# 101/101 [==============================] - 375s - loss: 108.9820 - val_loss: 110.6408
# Epoch 14/30
# 101/101 [==============================] - 378s - loss: 105.9472 - val_loss: 109.2300
# Epoch 15/30
# 101/101 [==============================] - 371s - loss: 102.7245 - val_loss: 109.3915
# Epoch 16/30
# 101/101 [==============================] - 375s - loss: 99.9679 - val_loss: 104.2226
# Epoch 17/30
# 101/101 [==============================] - 375s - loss: 97.5032 - val_loss: 106.5346
# Epoch 18/30
# 101/101 [==============================] - 374s - loss: 94.7832 - val_loss: 104.1999
# Epoch 19/30
# 101/101 [==============================] - 374s - loss: 92.1859 - val_loss: 102.2910
# Epoch 20/30
# 101/101 [==============================] - 374s - loss: 89.8623 - val_loss: 100.5774
# Epoch 21/30
# 101/101 [==============================] - 372s - loss: 88.1483 - val_loss: 98.4988
# Epoch 22/30
# 101/101 [==============================] - 377s - loss: 85.9329 - val_loss: 100.5480
# Epoch 23/30
# 101/101 [==============================] - 377s - loss: 83.7965 - val_loss: 100.0540
# Epoch 24/30
# 101/101 [==============================] - 379s - loss: 82.1722 - val_loss: 100.4201
# Epoch 25/30
# 101/101 [==============================] - 377s - loss: 80.2373 - val_loss: 97.9746
# Epoch 26/30
# 101/101 [==============================] - 373s - loss: 78.6847 - val_loss: 97.6619
# Epoch 27/30
# 101/101 [==============================] - 376s - loss: 77.5021 - val_loss: 97.4540
# Epoch 28/30
# 101/101 [==============================] - 377s - loss: 75.6564 - val_loss: 97.3563
# Epoch 29/30
# 101/101 [==============================] - 378s - loss: 74.4267 - val_loss: 96.5801
# Epoch 30/30
# 101/101 [==============================] - 376s - loss: 72.6892 - val_loss: 97.1804

# %%
model_end_30_04 = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3,
                        dropout_rate=0.4
                        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,931,629
# Trainable params: 2,931,229
# Non-trainable params: 400
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_end_30_04, 
            pickle_path='model_end_30_04.pickle', 
            save_model_path='model_end_30_04.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/30
# 101/101 [==============================] - 384s - loss: 261.5978 - val_loss: 225.4966
# Epoch 2/30
# 101/101 [==============================] - 392s - loss: 223.4333 - val_loss: 202.6245
# Epoch 3/30
# 101/101 [==============================] - 391s - loss: 205.0095 - val_loss: 180.8901
# Epoch 4/30
# 101/101 [==============================] - 392s - loss: 184.6242 - val_loss: 163.4621
# Epoch 5/30
# 101/101 [==============================] - 399s - loss: 170.2378 - val_loss: 154.3459
# Epoch 6/30
# 101/101 [==============================] - 391s - loss: 158.5963 - val_loss: 141.1137
# Epoch 7/30
# 101/101 [==============================] - 393s - loss: 149.3920 - val_loss: 138.1453
# Epoch 8/30
# 101/101 [==============================] - 391s - loss: 142.3630 - val_loss: 132.0295
# Epoch 9/30
# 101/101 [==============================] - 389s - loss: 136.2119 - val_loss: 127.3155
# Epoch 10/30
# 101/101 [==============================] - 391s - loss: 131.5444 - val_loss: 122.5173
# Epoch 11/30
# 101/101 [==============================] - 391s - loss: 127.2391 - val_loss: 119.7557
# Epoch 12/30
# 101/101 [==============================] - 389s - loss: 122.9675 - val_loss: 117.5758
# Epoch 13/30
# 101/101 [==============================] - 388s - loss: 119.7376 - val_loss: 115.4367
# Epoch 14/30
# 101/101 [==============================] - 390s - loss: 116.5498 - val_loss: 114.0444
# Epoch 15/30
# 101/101 [==============================] - 390s - loss: 114.0591 - val_loss: 110.0994
# Epoch 16/30
# 101/101 [==============================] - 389s - loss: 111.3826 - val_loss: 109.6528
# Epoch 17/30
# 101/101 [==============================] - 397s - loss: 108.8459 - val_loss: 109.2679
# Epoch 18/30
# 101/101 [==============================] - 398s - loss: 106.7041 - val_loss: 106.2419
# Epoch 19/30
# 101/101 [==============================] - 390s - loss: 104.7318 - val_loss: 106.0107
# Epoch 20/30
# 101/101 [==============================] - 390s - loss: 102.6139 - val_loss: 103.8771
# Epoch 21/30
# 101/101 [==============================] - 388s - loss: 100.5956 - val_loss: 102.7889
# Epoch 22/30
# 101/101 [==============================] - 392s - loss: 99.0390 - val_loss: 104.0572
# Epoch 23/30
# 101/101 [==============================] - 397s - loss: 97.3380 - val_loss: 103.0361
# Epoch 24/30
# 101/101 [==============================] - 391s - loss: 96.1588 - val_loss: 102.1918
# Epoch 25/30
# 101/101 [==============================] - 394s - loss: 94.6214 - val_loss: 101.4507
# Epoch 26/30
# 101/101 [==============================] - 396s - loss: 93.1839 - val_loss: 100.0967
# Epoch 27/30
# 101/101 [==============================] - 393s - loss: 91.8846 - val_loss: 98.2917
# Epoch 28/30
# 101/101 [==============================] - 389s - loss: 89.8812 - val_loss: 100.0904
# Epoch 29/30
# 101/101 [==============================] - 391s - loss: 88.9326 - val_loss: 98.1031
# Epoch 30/30
# 101/101 [==============================] - 393s - loss: 87.4518 - val_loss: 98.0197

# %%
# Use MFCC features
model_end_30_04_MFCC = final_model(input_dim=13, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3,
                        dropout_rate=0.4
                        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         28800
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_21 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,606,029
# Trainable params: 2,605,629
# Non-trainable params: 400
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_end_30_04_MFCC, 
            pickle_path='model_end_30_04_MFCC.pickle', 
            save_model_path='model_end_30_04_MFCC.h5', 
            spectrogram=False) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/30
# 101/101 [==============================] - 398s - loss: 251.3868 - val_loss: 219.1245
# Epoch 2/30
# 101/101 [==============================] - 400s - loss: 219.8922 - val_loss: 202.0196
# Epoch 3/30
# 101/101 [==============================] - 397s - loss: 203.6877 - val_loss: 182.6201
# Epoch 4/30
# 101/101 [==============================] - 403s - loss: 183.7901 - val_loss: 162.5879
# Epoch 5/30
# 101/101 [==============================] - 396s - loss: 168.2728 - val_loss: 153.4708
# Epoch 6/30
# 101/101 [==============================] - 399s - loss: 156.7082 - val_loss: 139.2879
# Epoch 7/30
# 101/101 [==============================] - 401s - loss: 147.7925 - val_loss: 134.5562
# Epoch 8/30
# 101/101 [==============================] - 396s - loss: 140.7509 - val_loss: 126.5288
# Epoch 9/30
# 101/101 [==============================] - 401s - loss: 135.1826 - val_loss: 125.3825
# Epoch 10/30
# 101/101 [==============================] - 403s - loss: 130.4193 - val_loss: 119.6895
# Epoch 11/30
# 101/101 [==============================] - 404s - loss: 126.4343 - val_loss: 117.9071
# Epoch 12/30
# 101/101 [==============================] - 401s - loss: 122.5892 - val_loss: 113.8993
# Epoch 13/30
# 101/101 [==============================] - 398s - loss: 119.7243 - val_loss: 112.8511
# Epoch 14/30
# 101/101 [==============================] - 402s - loss: 116.4932 - val_loss: 111.2219
# Epoch 15/30
# 101/101 [==============================] - 404s - loss: 114.0111 - val_loss: 107.3626
# Epoch 16/30
# 101/101 [==============================] - 401s - loss: 111.4806 - val_loss: 106.2464
# Epoch 17/30
# 101/101 [==============================] - 400s - loss: 109.3388 - val_loss: 104.7863
# Epoch 18/30
# 101/101 [==============================] - 395s - loss: 107.1663 - val_loss: 103.6969
# Epoch 19/30
# 101/101 [==============================] - 397s - loss: 105.2195 - val_loss: 102.5903
# Epoch 20/30
# 101/101 [==============================] - 401s - loss: 103.4703 - val_loss: 101.0945
# Epoch 21/30
# 101/101 [==============================] - 400s - loss: 101.9261 - val_loss: 100.7003
# Epoch 22/30
# 101/101 [==============================] - 399s - loss: 99.8805 - val_loss: 99.0658
# Epoch 23/30
# 101/101 [==============================] - 397s - loss: 98.1723 - val_loss: 100.0767
# Epoch 24/30
# 101/101 [==============================] - 398s - loss: 96.8082 - val_loss: 97.2673
# Epoch 25/30
# 101/101 [==============================] - 401s - loss: 95.4086 - val_loss: 97.0080
# Epoch 26/30
# 101/101 [==============================] - 400s - loss: 93.9637 - val_loss: 96.8532
# Epoch 27/30
# 101/101 [==============================] - 395s - loss: 92.5506 - val_loss: 98.0920
# Epoch 28/30
# 101/101 [==============================] - 402s - loss: 91.4756 - val_loss: 94.9393
# Epoch 29/30
# 101/101 [==============================] - 402s - loss: 90.2419 - val_loss: 94.1335
# Epoch 30/30
# 101/101 [==============================] - 404s - loss: 89.0934 - val_loss: 93.2459

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

# obtain the paths for the saved model history
all_pickles = sorted(glob("results/model_end_20*.pickle"))
# extract the name of each model
model_names = [item[8:-7] for item in all_pickles]
# extract the loss history for each model
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
# save the number of epochs used to train each model
num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

fig = plt.figure(figsize=(16,5))

# plot the training loss vs. epoch for each model
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
# clean up the plot
ax1.legend()  
ax1.set_xlim([1, max(num_epochs)])
ax1.set_ylim([70, 150])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title("Figure 1a: Training loss with 20 epochs of training")

# plot the validation loss vs. epoch for each model
ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
# clean up the plot
ax2.legend()  
ax2.set_xlim([1, max(num_epochs)])
ax2.set_ylim([90, 150])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title("Figure 1b: Validation loss with 20 epochs of training")
plt.show()

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

# obtain the paths for the saved model history
all_pickles = sorted(glob("results/model_end_30*.pickle"))
# extract the name of each model
model_names = [item[8:-7] for item in all_pickles]
# extract the loss history for each model
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
# save the number of epochs used to train each model
num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

fig = plt.figure(figsize=(16,5))

# plot the training loss vs. epoch for each model
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
# clean up the plot
ax1.legend()  
ax1.set_xlim([1, max(num_epochs)])
ax1.set_ylim([50, 150])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title("Figure 2a: Training loss with 30 epochs of training")

# plot the validation loss vs. epoch for each model
ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
# clean up the plot
ax2.legend()  
ax2.set_xlim([1, max(num_epochs)])
ax2.set_ylim([90, 150])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title("Figure 2b: Validation loss with 30 epochs of training")
plt.show()

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

# obtain the paths for the saved model history
all_pickles = sorted(glob("results/model_end.pickle"))
# extract the name of each model
model_names = [item[8:-7] for item in all_pickles]
# extract the loss history for each model
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
# save the number of epochs used to train each model
num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

fig = plt.figure(figsize=(16,5))

# plot the training loss vs. epoch for each model
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
# clean up the plot
ax1.legend()  
ax1.set_xlim([1, max(num_epochs)])
ax1.set_ylim([80, 150])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title("Figure 3a: Training loss of the final model")

# plot the validation loss vs. epoch for each model
ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
# clean up the plot
ax2.legend()  
ax2.set_xlim([1, max(num_epochs)])
ax2.set_ylim([80, 150])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title("Figure 3b: Validation loss of the final model")
plt.show()

# %% [markdown]
# __Question 2:__ Describe your final model architecture and your reasoning at each step.
#
# __Answer:__
#
# Based on the analysis performed in Question 1 above, I have chosen to use the deep bidirectional LSTM model as the starting point. The model 5 that I have implemented in Question 1 was overfitting to the training dataset (training loss 64 vs. validation loss 137); therefore, I have decided to implement a dropout to reduce the overfitting problem. The default of 0.2 was used for the dropout rate. Also, I have decided to increase the RNN layers from 2 to 3, as more RNN layers will enhance the performance of the model, however, this is a tradeoff with the computational time. Lastly, I have implemented a CNN layer before the RNN layers, as Model 2 (CNN + RNN (GRU) + TimeDistributed Dense) in Questions 1 also performed well in the training dataset. Figure 1 above shows the initial result of the model performance.
#
# As you can see from figure 1 above, the model was still facing the overfitting problem; hence, I have increased the dropout rate and tested the rate of 0.3 and 0.4 to look for the best rate to reduce the overfitting problem. Also, both the training and validation loss of the model were still decreasing after completing all 20 epochs of training; therefore I have decided to increase the number of epochs from 20 to 30 to further improve its accuracy. Lastly, I have decided to use MFCC features since MFCC features had slightly better performance based on figure 1. Figure 2 above shows the results of this model comparison.
#
# With the dropout rate of 0.4 and 30 epochs of training using MFCC features, my final model was able to achieve the training loss of 89 and validation loss of 93 (figure 3); hence, my final model increase the performance by more than 30% compared to the best model (Model 5) in Question 1. The following are the details of the model architecture:
# - Convolutional layer
# - Batch normalization layer
# - 3 layers of Bidirectional LSTM with the dropout rate of 0.4
# - TimeDistributed layer

# %% [markdown]
# <a id='step3'></a>
# ## STEP 3: Obtain Predictions
#
# We have written a function for you to decode the predictions of your acoustic model.  To use the function, please execute the code cell below.

# %%
import numpy as np
from data_generator import AudioGenerator
from keras import backend as K
from utils import int_sequence_to_text
from IPython.display import Audio

def get_predictions(index, partition, input_to_softmax, model_path):
    """ Print a model's decoded predictions
    Params:
        index (int): The example you would like to visualize
        partition (str): One of 'train' or 'validation'
        input_to_softmax (Model): The acoustic model
        model_path (str): Path to saved acoustic model's weights
    """
    # load the train and test data
    data_gen = AudioGenerator(spectrogram=False)
    data_gen.load_train_data()
    data_gen.load_validation_data()
    
    # obtain the true transcription and the audio features 
    if partition == 'validation':
        transcr = data_gen.valid_texts[index]
        audio_path = data_gen.valid_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    elif partition == 'train':
        transcr = data_gen.train_texts[index]
        audio_path = data_gen.train_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    else:
        raise Exception('Invalid partition!  Must be "train" or "validation"')
        
    # obtain and decode the acoustic model's predictions
    input_to_softmax.load_weights(model_path)
    prediction = input_to_softmax.predict(np.expand_dims(data_point, axis=0))
    output_length = [input_to_softmax.output_length(data_point.shape[0])] 
    pred_ints = (K.eval(K.ctc_decode(
                prediction, output_length)[0][0])+1).flatten().tolist()
    
    # play the audio file, and display the true and predicted transcriptions
    print('-'*80)
    Audio(audio_path)
    print('True transcription:\n' + '\n' + transcr)
    print('-'*80)
    print('Predicted transcription:\n' + '\n' + ''.join(int_sequence_to_text(pred_ints)))
    print('-'*80)

# %% [markdown]
# Use the code cell below to obtain the transcription predicted by your final model for the first example in the training dataset.

# %%
get_predictions(index=0, 
                partition='train',
                input_to_softmax=final_model3(input_dim=13, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3
                        ), 
                model_path='results/model_end_30_04_MFCC.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         28800
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_34 (Bidirectio (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_35 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_36 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,606,029
# Trainable params: 2,605,629
# Non-trainable params: 400
# _________________________________________________________________
# None
# --------------------------------------------------------------------------------
# True transcription:
#
# mister quilter is the apostle of the middle classes and we are glad to welcome his gospel
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# mis te culteris the apposoof to mitl classes and wearglad towel im his gospl
# --------------------------------------------------------------------------------

# %% [markdown]
# Use the next code cell to visualize the model's prediction for the first example in the validation dataset.

# %%
get_predictions(index=0, 
                partition='validation',
                input_to_softmax=final_model3(input_dim=13, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200,
                        recur_layers=3
                        ), 
                model_path='results/model_end_30_04_MFCC.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         28800
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_37 (Bidirectio (None, None, 400)         641600
# _________________________________________________________________
# bidirectional_38 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# bidirectional_39 (Bidirectio (None, None, 400)         961600
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,606,029
# Trainable params: 2,605,629
# Non-trainable params: 400
# _________________________________________________________________
# None
# --------------------------------------------------------------------------------
# True transcription:
#
# stuff it into you his belly counselled him
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# stefo into you his pely cotol him
# --------------------------------------------------------------------------------

# %% [markdown]
# One standard way to improve the results of the decoder is to incorporate a language model.  We won't pursue this in the notebook, but you are welcome to do so as an _optional extension_.
#
# If you are interested in creating models that provide improved transcriptions, you are encouraged to download [more data](http://www.openslr.org/12/) and train bigger, deeper models.  But beware - the model will likely take a long while to train.  For instance, training this [state-of-the-art](https://arxiv.org/pdf/1512.02595v1.pdf) model would take 3-6 weeks on a single GPU!
